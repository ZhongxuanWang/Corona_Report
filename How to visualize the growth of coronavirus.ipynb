# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("us-states.csv")
data
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 2044  2020-04-08       Virginia    51   3645      75
# 2045  2020-04-08     Washington    53   9097     454
# 2046  2020-04-08  West Virginia    54    483       4
# 2047  2020-04-08      Wisconsin    55   2756     107
# 2048  2020-04-08        Wyoming    56    230       0
#
# [2049 rows x 5 columns]

# %%
a = data.groupby(data["date"]).aggregate({'cases':'sum'})

a
# Out:
#              cases
# date
# 2020-01-21       1
# 2020-01-22       1
# 2020-01-23       1
# 2020-01-24       2
# 2020-01-25       3
# ...            ...
# 2020-04-04  311536
# 2020-04-05  336774
# 2020-04-06  366238
# 2020-04-07  397754
# 2020-04-08  429319
#
# [79 rows x 1 columns]

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,2,2])
ax.set_xlabel("The # of days")
ax.set_ylabel("Cases")

x = np.arange(len(a["cases"]))
y = a["cases"]
ax.plot( x , y )
ax.scatter(x,y)

ax.set_title("The growth of coronavirus in america")
# Out:
# Text(0.5, 1.0, 'The growth of coronavirus in america')

# %%
fig.savefig("corogrowth.png", bbox_inches="tight")
